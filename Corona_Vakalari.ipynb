# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("/content/corona.xltx")
data
# Out:
#                           tarih  haftalık_vaka  haftalık_vefat  \
# 0      25 Temmuz 1 Ağustos 2022         406322             337
# 1            18 -24 Temmuz 2022         365424             157
# 2           11 - 17 Temmuz 2022         226532              96
# 3            4 - 10 Temmuz 2022         117095              31
# 4   27 Haziran - 03 Temmuz 2022          57113              25
# 5  20 Haziran - 26 Haziran 2022          26635              17
# 6  13 Haziran - 19 Haziran 2022          10954              19
# 7   06 Haziran -12 Haziran 2022           7556              20
# 8    30 Mayıs - 05 Haziran 2022           7322              19
#
#    haftalık_iyilesen  toplam_vaka  toplam_vefat
# 0             387653     16295817         99678
# 1             265962     15889495         99341
# 2             124732     15524071         99184
# 3              61047     15297539         99088
# 4              30478     15180444         99057
# ...

# %%
data["tarih"]
# Out:
# 0        25 Temmuz 1 Ağustos 2022
# 1              18 -24 Temmuz 2022
# 2             11 - 17 Temmuz 2022
# 3              4 - 10 Temmuz 2022
# 4     27 Haziran - 03 Temmuz 2022
# 5    20 Haziran - 26 Haziran 2022
# 6    13 Haziran - 19 Haziran 2022
# 7     06 Haziran -12 Haziran 2022
# 8      30 Mayıs - 05 Haziran 2022
# Name: tarih, dtype: object

# %%
y=[data["tarih"]]
y
# Out:
# [0        25 Temmuz 1 Ağustos 2022
#  1              18 -24 Temmuz 2022
#  2             11 - 17 Temmuz 2022
#  3              4 - 10 Temmuz 2022
#  4     27 Haziran - 03 Temmuz 2022
#  5    20 Haziran - 26 Haziran 2022
#  6    13 Haziran - 19 Haziran 2022
#  7     06 Haziran -12 Haziran 2022
#  8      30 Mayıs - 05 Haziran 2022
#  Name: tarih, dtype: object]

# %%
x=[data['haftalık_iyilesen']]
x2=[data["haftalık_vefat"]]
x3=[data['haftalık_vaka']]
x4=[data['toplam_vaka']]
x5=[data['toplam_vefat']]

# %%
plt.plot(data['haftalık_vaka'],data['haftalık_vefat'],'b-',label="Haftalik(Vaka/Vefat)")
plt.xlabel("Haftalik Vaka")
plt.ylabel("Haftalik Ölüm")
plt.legend()
plt.show()

# %%
plt.plot(data['haftalık_vaka'],data['haftalık_iyilesen'],'g-',label="Haftalik(Vaka/Iyilesen)")
plt.xlabel("Haftalik Vaka")
plt.ylabel("Haftalik Iyilesen")
plt.legend()
plt.show()

# %%
plt.plot(data['toplam_vaka'],data['toplam_vefat'],'g-',label="Toplam(Vaka/vefat)")
plt.xlabel("Toplam Vaka")
plt.ylabel("Toplam Vefat")
plt.legend()
plt.show()

# %%
plt.scatter(data['toplam_vefat'],data['toplam_vaka'])

# %%
plt.scatter(data['haftalık_iyilesen'],data['haftalık_vefat'])

# %%
plt.bar(data['toplam_vefat'],data['toplam_vaka'])
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(data['haftalık_vefat'],data['haftalık_vaka'])
# Out:
# <BarContainer object of 9 artists>

# %%
plt.subplot(131)#Buarada diyoruz ki 1 satir 3 sütundan olusan 1.grafik plot olsun 
plt.plot(data['haftalık_vaka'],data['haftalık_vefat'],'b-',label="Haftalik(Vaka/Vefat)")
plt.xlabel("Haftalik Vaka")
plt.ylabel("Haftalik Ölüm")

plt.subplot(132)#Buarada diyoruz ki 1 satir 3 sütundan olusan 2.grafik scatter olsun 
plt.plot(data['haftalık_vaka'],data['haftalık_iyilesen'],'g-',label="Haftalik(Vaka/Iyilesen)")
plt.xlabel("Haftalik Vaka")
plt.ylabel("Haftalik Iyilesen")

plt.subplot(133)#Buarada diyoruz ki 1 satir 3 sütundan olusan 3.grafik bar olsun 
plt.plot(data['toplam_vaka'],data['toplam_vefat'],'g-',label="Toplam(Vaka/vefat)")
plt.xlabel("Toplam Vaka")
plt.ylabel("Toplam Vefat")

plt.suptitle("Bütün Grafiklerin Ortak Basligi")#Bu da bütün grafiklerin ortak basligi
# Out:
# Text(0.5, 0.98, 'Bütün Grafiklerin Ortak Basligi')

# %%
plt.bar(data['tarih'],data['toplam_vaka'],label="Toplam(Vaka/vefat)")
plt.xlabel("Toplam Vaka")
plt.ylabel("Toplam Vefat")
plt.legend()
plt.show()

# %%
plt.bar(data['tarih'],data['toplam_vefat'],label="Toplam(Vaka/vefat)")
plt.xlabel("Toplam Vaka")
plt.ylabel("Toplam Vefat")
plt.legend()
plt.show()

# %%
plt.barh(data['tarih'],data['haftalık_iyilesen'])
plt.xlabel("iyilesen")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.barh(data['tarih'],data['haftalık_vefat'])
plt.xlabel("Haftalik Vefat")

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.barh(data['tarih'],data['haftalık_vaka'],)
plt.xlabel("Toplam Vaka")

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.barh(data['tarih'],data['toplam_vaka'])
plt.xlabel("ToplamVaka")

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
